# %%
# Note: Replace **<YOUR_APPLICATION_TOKEN>** with your actual Application token
import requests
# The complete API endpoint URL for this flow
url = f"https://api.langflow.astra.datastax.com/lf/53268fa9-a41c-4739-b45f-baadf4e7c115/api/v1/run/40aa8d10-1462-46a1-8abd-26ee0e18e25c"

# Request payload configuration
payload = {
    "input_value": "What is the document is about?",  # The input value to be processed by the flow
    "output_type": "chat",  # Specifies the expected output format
    "input_type": "chat"  # Specifies the input format
}

# Request headers
headers = {
    "Content-Type": "application/json",
    "Authorization": "Bearer AstraCS:QiyLhngITfajpAgDlkWtGcmR:244019617bb0330e0ce83bad1945ddaaafba4d13ab55f44f1c4df3ff6319fabe"  # Authentication key from environment variable'}
}

try:
    # Send API request
    response = requests.request("POST", url, json=payload, headers=headers)
    response.raise_for_status()  # Raise exception for bad status codes

    # Print response
    print(response.text)

except requests.exceptions.RequestException as e:
    print(f"Error making API request: {e}")
except ValueError as e:
    print(f"Error parsing response: {e}")
# Out:
# {"session_id":"40aa8d10-1462-46a1-8abd-26ee0e18e25c","outputs":[{"inputs":{"input_value":"What is the document is about?"},"outputs":[{"results":{"message":{"text_key":"text","data":{"timestamp":"2025-06-09T06:57:17+00:00","sender":"Machine","sender_name":"AI","session_id":"40aa8d10-1462-46a1-8abd-26ee0e18e25c","text":"The document is a sample of frequently asked questions (Q&As) for a restaurant. It covers various topics such as gift cards, COVID-19 precautions, outdoor seating, private events, Wi-Fi, hours of operation, location, parking, reservations, and menu options.\n","files":[],"error":false,"edit":false,"properties":{"text_color":"","background_color":"","edited":false,"source":{"id":"GoogleGenerativeAIModel-ZiwW5","display_name":"Google Generative AI","source":"learnlm-2.0-flash-experimental"},"icon":"GoogleGenerativeAI","allow_markdown":false,"positive_feedback":null,"state":"complete","targets":[]},"category":"message","content_blocks":[],"id":"ff83b9e4-107a-4709-8d2f-3c2
# ...

# %%
from IPython.display import display, Image

# Replace 'VectorDB_Data_Ingestion.png' with the actual path to your image file
image_path = 'VectorDB_Data_Ingestion.png'

try:
    # Display the image
    display(Image(filename=image_path))
except FileNotFoundError:
    print(f"Error: Image file not found at '{image_path}'")
except Exception as e:
    print(f"An error occurred while displaying the image: {e}")

# %%
from IPython.display import display, Image

# Replace 'VectorDB_Data_Ingestion.png' with the actual path to your image file
image_path = 'VectorDB_Data_Retrieval.png'

try:
    # Display the image
    display(Image(filename=image_path))
except FileNotFoundError:
    print(f"Error: Image file not found at '{image_path}'")
except Exception as e:
    print(f"An error occurred while displaying the image: {e}")
